# %% [markdown]
# <a href="https://colab.research.google.com/github/eom-hope/ABCD-A/blob/20250516/%EB%8B%A4%EC%96%91%ED%95%9C_%EB%AC%B8%EC%9E%90%EC%97%B4_%ED%95%A8%EC%88%98_%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 'I Love Python'
print( len(a) )
# Out:
# 13

# %%
a = [1, 2, 3]
print(min(a))

b = 'BlockDMask'
print(min(b))

c = 1

d = (6, 5, 4, 2)
print(min(d)) #

e = [3, 4, 5, 'a', 'b', 'c']
# Out:
# 1
# B
# 2

# %%
a = [1, 2, 3]
b = [4, 5, 6]
print(min(a, b))

c = 'BlockDMask'
d = 'BAAAlockDMask'
print(min(c, d))

e = [3, 2, 1]
f = ['a', 3, 2, 1]

g = [2, 3, 4]
h = [2, 2, 2, 2, 2]
i = [9, 8, 7, 6, 5]
j = [1]
k = [0]
print(min(g, h, i, j, k))
# Out:
# [1, 2, 3]
# BAAAlockDMask
# [0]

# %%
myString = "everdevel"
print(myString.count('e'))
a = 'BlockDMask'

print('#1 a.count("k")')
print(a.count('k'))
print('#2 a.count("DM")')
print(a.count('DM'))

print("#3 a[2] + ' ~ ' + a[4]")
print(a[2] + ' ~ ' + a[4])
print("#4 a.count('k', 2, 3)")
print(a.count('k', 2, 3))
print("#5 a.count('k', 2, 4)")
print(a.count('k', 2, 4))
print("#6 a.count('k', 2, 5)")
print(a.count('k', 2, 5))
# Out:
# 4
# #1 a.count("k")
# 2
# #2 a.count("DM")
# 1
# #3 a[2] + ' ~ ' + a[4]
# o ~ k
# #4 a.count('k', 2, 3)
# 0
# #5 a.count('k', 2, 4)
# 0
# #6 a.count('k', 2, 5)
# 1

# %%
str="BlockDMask Blog.";
print(f"str : {str}\n")

print("1. str.find('찾을 문자')")
result1 = str.find('a')

result2 = str.find('Z')

print(f"str.find('a') : {result1}")
print(f"str.find('Z') : {result2}")
result3 = str.find('ask')

result4 = str.find('kkk')

print(f"str.find('ask') : {result3}")
print(f"str.find('kkk') : {result4}")
print()

print("2. str.find('찾을 문자', 시작index)")
result5 = str.find('o')
result6 = str.find('o', 5)
print(f"str.find('o') : {result5}")
print(f"str[5] : {str[5]}")
print(f"str.find('o', 5) : {result6}")
print()

print("3. str.find('찾을 문자', 시작 index, 끝 index)")
result7 = str.find('o')
result8 = str.find('o', 5, 11)

print(f"str.find('o') : {result7}")
print(f"str[5]~str[11] : {str[5]} ~ {str[11]}")
print(f"str.find('o', 5, 11) : {result8}")
# Out:
# str : BlockDMask Blog.
#
# 1. str.find('찾을 문자')
# str.find('a') : 7
# str.find('Z') : -1
# str.find('ask') : 7
# str.find('kkk') : -1
#
# 2. str.find('찾을 문자', 시작index)
# str.find('o') : 2
# str[5] : D
# str.find('o', 5) : 13
#
# 3. str.find('찾을 문자', 시작 index, 끝 index)
# str.find('o') : 2
# str[5]~str[11] : D ~ B
# str.find('o', 5, 11) : -1

# %%
str = 'Hello world, Python!'

if str.startswith('Hello'):
    print('It starts with Hello')

if not str.startswith('Python'):
    print('It does not start with Python')
# Out:
# It starts with Hello
# It does not start with Python

# %%
str = "this is string example....wow!!!"

suffix = "wow!!!"
print(str.endswith(suffix))
print(str.endswith(suffix,20))

suffix = "is"
print(str.endswith(suffix, 2, 4))
print(str.endswith(suffix, 2, 6))
# Out:
# True
# True
# True
# False

# %%
text = 'Welcome to Codetorial'

pos_e_last = text.rfind('e')
print(pos_e_last)

pos_e_first = text.find('e')
print(pos_e_first)

pos_to_last = text.rfind('to')
print(pos_to_last)

pos_to_first = text.find('to')
print(pos_to_first)
# Out:
# 14
# 1
# 15
# 8

# %%
nums_list = [1,2,3,3,3,5,6,8,9]
nums_tuple = (1,2,3,3,3,5,6,8,9)
nums_set = {1,2,3,5,6,8,9}

print(nums_list.index(2))
print(nums_list.index(3))


print(nums_tuple.index(2))
print(nums_tuple.index(3))

str = 'kangminheee'
print(str.index('k'))
print(str.index('h'))
print(str.index('i'))
#print(str.index('l'))
print(str.index('e'))
print(str.find('e'))
print(str.rfind('e'))
# Out:
# 1
# 2
# 1
# 2
# 0
# 7
# 5
# 8
# 8
# 10

# %%
hz = "홈짱닷컴 Homzzang.com"

x = hz.rindex("Homzzang")

print(x)

x = hz.rindex("o", 2)
print(x)
text = 'Welcome to Codetorial'

pos_Code_last = text.rindex('Code')
print(pos_Code_last)
# Out:
# 5
# 15
# 11
