# %% [markdown]
# <a href="https://colab.research.google.com/github/eom-hope/ABCD-A/blob/20250331/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B2%A1%ED%84%B0_%ED%95%A9%EA%B3%BC_%EB%82%B4%EC%A0%81%2C_%EC%99%B8%EC%A0%81_%EA%B3%84%EC%82%B0%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2

dot_product = sum_x * sum_y  # 내적 계산 수정
cross_product = sum_x * y2 - sum_y * x2  # 외적 계산 수정

print("\n벡터 1:", x1, "i +", y1, "j")
print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 3
# 첫 번째 벡터의 y 성분을 입력하세요: 4
# 두 번째 벡터의 x 성분을 입력하세요: 5
# 두 번째 벡터의 y 성분을 입력하세요: 6
#
# 벡터 1: 3.0 i + 4.0 j
# 벡터 2: 5.0 i + 6.0 j
#
# 벡터의 합: 8.0 i + 10.0 j
# 벡터의 내적: 80.0
# 벡터의 외적: -2.0

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
z1 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))
z2 = float(input("두 번째 벡터의 z 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2
sum_z = z1 + z2

dot_product = sum_x * sum_y + sum_z * (x1 + x2)  # 내적 계산 변경
cross_product_x = sum_y * z2 - sum_z * y2  # 외적 계산 변경
cross_product_y = sum_z * x2 - sum_x * z2
cross_product_z = sum_x * y2 - sum_y * x2

print("\n벡터 1:", x1, "i +", y1, "j +", z1, "k")
print("벡터 2:", x2, "i +", y2, "j +", z2, "k")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j +", sum_z, "k")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product_x, "i +", cross_product_y, "j +", cross_product_z, "k")
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 4
# 첫 번째 벡터의 y 성분을 입력하세요: 5
# 첫 번째 벡터의 z 성분을 입력하세요: 6
# 두 번째 벡터의 x 성분을 입력하세요: 7
# 두 번째 벡터의 y 성분을 입력하세요: 8
# 두 번째 벡터의 z 성분을 입력하세요: 9
#
# 벡터 1: 4.0 i + 5.0 j + 6.0 k
# 벡터 2: 7.0 i + 8.0 j + 9.0 k
#
# 벡터의 합: 11.0 i + 13.0 j + 15.0 k
# 벡터의 내적: 308.0
# 벡터의 외적: -3.0 i + 6.0 j + -3.0 k
