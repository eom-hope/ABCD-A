# %% [markdown]
# <a href="https://colab.research.google.com/github/eom-hope/ABCD-A/blob/20250406/3%EC%9E%A5_%EA%B1%B4%EB%AC%BC_%EC%98%A5%EC%83%81%EC%97%90%EC%84%9C_%EC%88%98%ED%8F%89%EC%9C%BC%EB%A1%9C_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%AC%B8%EC%A0%9C_%ED%92%80%EC%9D%B4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

t = float(input("공이 떨어지기까지 걸린 시간 (초)을 입력하세요 (예: 2): "))
x = float(input("수평 거리 (m)를 입력하세요 (예: 20): "))
2
g = 9.81
v0 = x / t

y = 0.5 * g * t**2

vx = v0
vy = g * t

v = math.sqrt(vx**2 + vy**2)

theta_rad = math.atan(vy / vx)
theta_deg = math.degrees(theta_rad)

print("\n[결과]")
print(f"a) 공의 처음 속도 크기: {v0:.2f} m/s")
print(f"b) 건물 높이: {y:.2f} m")
print(f"c) 충돌 순간 속도 크기: {v:.2f} m/s")
print(f"   충돌 순간 속도 방향 (수평선과 이루는 각도): {theta_deg:.2f}도")
# Out:
# 공이 떨어지기까지 걸린 시간 (초)을 입력하세요 (예: 2): 5
# 수평 거리 (m)를 입력하세요 (예: 20): 40
#
# [결과]
# a) 공의 처음 속도 크기: 8.00 m/s
# b) 건물 높이: 122.62 m
# c) 충돌 순간 속도 크기: 49.70 m/s
#    충돌 순간 속도 방향 (수평선과 이루는 각도): 80.74도
