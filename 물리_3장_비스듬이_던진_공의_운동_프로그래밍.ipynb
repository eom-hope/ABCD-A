# %% [markdown]
# <a href="https://colab.research.google.com/github/eom-hope/ABCD-A/blob/20250415/%EB%AC%BC%EB%A6%AC_3%EC%9E%A5_%EB%B9%84%EC%8A%A4%EB%93%AC%EC%9D%B4_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# 초기 조건
y0 = 140  # 건물의 높이 (m)
v0 = 100  # 초기 속도 (m/s)
theta = math.radians(37)  # 각도 (rad)
g = 9.8  # 중력 가속도 (m/s^2)

# (a) 지면에 도달할 때까지의 시간 계산
a = -0.5 * g
b = v0 * math.sin(theta)
c = y0
t = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
print(f"(a) 지면에 도달할 때까지의 시간: {t:.2f}초")

# (b) 수평 거리 X 계산
vx = v0 * math.cos(theta)
x = vx * t
print(f"(b) 수평 거리 X: {x:.2f}m")

# (c) 충돌 직전 속도의 수평/수직 성분 계산
vy = v0 * math.sin(theta) - g * t
print(f"(c) 수평 속도 성분: {vx:.2f} m/s")
print(f"(c) 수직 속도 성분: {vy:.2f} m/s")

# (d) 속도의 크기 계산
v = math.sqrt(vx**2 + vy**2)
print(f"(d) 속도의 크기: {v:.2f} m/s")

# (e) 속도벡터와 수평선 사이의 각도 계산
angle = math.degrees(math.atan2(vy, vx))
print(f"(e) 속도벡터와 수평선 사이의 각도: {angle:.2f}°")
# Out:
# (a) 지면에 도달할 때까지의 시간: -2.00초
# (b) 수평 거리 X: -159.76m
# (c) 수평 속도 성분: 79.86 m/s
# (c) 수직 속도 성분: 79.79 m/s
# (d) 속도의 크기: 112.89 m/s
# (e) 속도벡터와 수평선 사이의 각도: 44.97°
