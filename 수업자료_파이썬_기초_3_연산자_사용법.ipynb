# %% [markdown]
# <a href="https://colab.research.google.com/github/eom-hope/ABCD-A/blob/20250321/%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%88_3_%EC%97%B0%EC%82%B0%EC%9E%90_%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4/3
# Out:
# 1.3333333333333333

# %%
1/2
# Out:
# 0.5

# %%
4/2
# Out:
# 2.0

# %%
7//3
# Out:
# 2

# %%
7%3
# Out:
# 1

# %%
2**10
# Out:
# 1024

# %%
int(5/2)
# Out:
# 2

# %%
5//2
# Out:
# 2

# %%
a=1024
print(a)
# Out:
# 1024

# %%
a+=1024
a
# Out:
# 2048

# %%
a-=1024
a
# Out:
# 1024

# %%
a*=4
a
# Out:
# 4096

# %%
a/=2
a
# Out:
# 2048.0

# %%
a//=2
a
# Out:
# 1024.0

# %%
a%=1022
a
# Out:
# 2.0

# %%
a**=10
a
# Out:
# 1024.0

# %%
divmod(5, 2)
# Out:
# (2, 1)

# %%
puotient, remainder = divmod(5, 2)
print(puotient, remainder)
# Out:
# 2 1

# %%
a = 11 + 2
b = 12 - 2
c = 13 * 2
d = 14 / 2
e = 15 ** 2
f = 16 // 2
g = 17 % 3
print( a, b, c, d, e, f, g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
a=10
++a
print(a)
# Out:
# 10

# %%
i=3
i+=3
print(i)
i-=3
print(i)
i*=2
print(i)
i/=2
print(int(i))
i=3
i%=2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
a = 10
b = 3
print("10 == 3 =>", a == b)
print("10 != 3 =>", a != b)
print("10 > 3 =>", a > b)
print("10 >= 3 =>", a >= b)
print("10 < 3 =>", a < b)
print("10 <= 3 =>", a <= b)
print()
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > 3 => True
# 10 >= 3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
bin(13)
# Out:
# '0b1101'

# %%
0b1101
# Out:
# 13

# %%
int('1101', 2)
# Out:
# 13

# %%
bin(0b1101&0b1001)
# Out:
# '0b1001'

# %%
13&9
# Out:
# 9

# %%
bin(0b1101 | 0b1001)
# Out:
# '0b1101'

# %%
13 | 9
# Out:
# 13

# %%
bin(0b1101 ^ 0b1001)
# Out:
# '0b100'

# %%
13^9
# Out:
# 4

# %%
bin(~0b1101)
# Out:
# '-0b1110'

# %%
~13
# Out:
# -14

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a|b))
print(a|b)
# Out:
# 0b1101
# 0b1001
# 0b1101
# 13

# %%
a = 12
b = 8
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)

print(bin(a))
print(bin(b))
print(bin(a|b))
print(a|b)

print(bin(a))
print(bin(b))
print(bin(a|b))
print(a|b)

print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)

print(bin(a))
print(bin(~a))
# Out:
# 0b1100
# 0b1000
# 0b1000
# 8
# 0b1100
# 0b1000
# 0b1100
# 12
# 0b1100
# 0b1000
# 0b1100
# 12
# 0b1100
# 0b1000
# 0b100
#
# 4
# 0b1100
# -0b1101

# %%
def power(a, b):
  num = 1
  for i in range(0, b):
    num = num * a
  return num

print(power(2, 3))
print(power(3, 2))
print(power(b = 2, a = 3))
# Out:
# 8
# 9
# 9
