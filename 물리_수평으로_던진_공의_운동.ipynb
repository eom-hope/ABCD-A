# %% [markdown]
# <a href="https://colab.research.google.com/github/eom-hope/ABCD-A/blob/20250410/%EB%AC%BC%EB%A6%AC_%EC%88%98%ED%8F%89%EC%9C%BC%EB%A1%9C_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %% [markdown]
# 수평으로 던진 공의 운동

# %%
# 초기속도 입력
vo=float(input())
print("초기속도:",vo,"m/s")
# Out:
#  30
# 초기속도: 30.0 m/s

# %%
#초기 각도 입력
angle_degree=float(input())
print("초기각도:",angle_degree,"도")

#각도를 radian으로바꾸기
angle_degree=math.radians(angle_degree)
print("초기각도:",angle_degree,"radian")
# Out:
# 30
# 초기각도: 30.0 도
# 초기각도: 0.5235987755982988 radian

# %%
#X 성분의 속도를 구하시오
vOx = math.cos(angle_degree) * vo
print("X축의 초기속도:", vOx, "m/s")
# Out:
# X축의 초기속도: 25.98076211353316 m/s

# %%
#Y 성분의 속도를 구하시오
vOy = math.sin(angle_degree) * vo
print("Y축의 초기속도:", vOy, "m/s")
# Out:
# Y축의 초기속도: 14.999999999999998 m/s

# %%
#최고점 높이
g= 9.8
h_max = (vOy**2) / (2 * g)
print("최고점 높이:", h_max, "m")
# Out:
# 최고점 높이: 11.467889908256877 m

# %%
#최고점 도달시간
t_max = vOy / g
print("최고점 도달 시간:", t_max, "초")
# Out:
# 최고점 도달 시간: 1.5290519877675839 초

# %%
# 4) 수평으로 이동한 거리 구하기
t_total = 2 * t_max  # 전체 비행 시간
dist = vOx * t_total
print("수평 이동 거리:", dist, "m")
# Out:
# 수평 이동 거리: 79.45187190682923 m

# %%
# 5) 지면에 닿을 때의 Vx, Vy와 V 구하기
vy_end = -vOy  # 최고점 이후 지면에 닿을 때 y 방향 속도
v_end = math.sqrt(vOx**2 + vy_end**2)
print("지면에 닿을 때 x 방향 속도:", vOx, "m/s")
print("지면에 닿을 때 y 방향 속도:", vy_end, "m/s")
print("지면에 닿을 때 속도 크기:", v_end, "m/s")
# Out:
# 지면에 닿을 때 x 방향 속도: 25.98076211353316 m/s
# 지면에 닿을 때 y 방향 속도: -14.999999999999998 m/s
# 지면에 닿을 때 속도 크기: 30.0 m/s
